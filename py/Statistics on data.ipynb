# %%
import os
import librosa
import _pickle as cPickle
from scipy.io.wavfile import read
from pathlib import Path
import warnings
import numpy as np
from sklearn import preprocessing
import python_speech_features as mfcc
warnings.filterwarnings("ignore")

# %%
#done
def durations(times):
    sum1=0
    for p in range(len(times)):
        j=float(times[p][1] - times[p][0])
        sum1 += j
    return sum1

# %%
#done
def time(path):
    file = open(path, "r")     
    times = []          
    for line in file:
        times.append([float(x) for x in line.strip().split( )[0:2]])
    file.close()
    return times

# %%
sum=sum1=sum2=sum3=sum4=sum5=sum6=sum7=sum8=sum9=sum10=sum11=sum12=sum13=sum14=sum15=sum16=sum17=sum18=0
sum19=sum20=sum21=sum22=sum23=sum24=sum25=sum26=sum27=0
female=0
male=0
train_file = "..\\data\\f_list\\lbl_list.txt"
file_paths = open(train_file,'r')
for path in file_paths:
    path = path.strip()
    file_name=os.path.basename(path)
    #print(file_name)
    split_filename=file_name.split('_')
    split_filename1=file_name.split('_')[0][4]
    #print(split_filename1)
    molecule_name=split_filename[0]
    #print(molecule_name)
    if split_filename1 =='F':
        if molecule_name=="S001F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum += p
        elif molecule_name=="S002F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum1 += p
        elif molecule_name=="S011F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum2 += p
        elif molecule_name=="S012F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum3 += p
        elif molecule_name=="S021F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum4 += p
        elif molecule_name=="S022F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum5 += p
        elif molecule_name=="S031F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum6 += p
        elif molecule_name=="S032F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum7 += p
        elif molecule_name=="S033F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum8 += p
        elif molecule_name=="S041F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum9 += p
        elif molecule_name=="S042F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum10 += p
        elif molecule_name=="S051F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum11 += p
        elif molecule_name=="S052F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum12 += p
        elif molecule_name=="S061F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum13 += p
        elif molecule_name=="S062F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum14 += p
        elif molecule_name=="S081F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum15 += p
        elif molecule_name=="S082F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum16 += p
        elif molecule_name=="S091F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum17 += p
        elif molecule_name=="S092F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum18 += p
        elif molecule_name=="S101F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum19 += p
        elif molecule_name=="S102F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum20 += p
        elif molecule_name=="S111F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum21 += p
        elif molecule_name=="S112F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum22 += p
        elif molecule_name=="S113F":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum23 += p
    
    else:
        if molecule_name=="S023M":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum24 += p
        elif molecule_name=="S071M":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum25 += p
        elif molecule_name=="S072M":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum26 += p
        elif molecule_name=="S073M":
            for pathlbl in path:
                times=time(path)
            p=durations(times)
            #print(p)
            sum27 += p
print("Duration of S001F = ",+sum)
print("Duration of S002F = ",+sum1)
print("Duration of S011F = ",+sum2)
print("Duration of S012F = ",+sum3)
print("Duration of S021F = ",+sum4)
print("Duration of S022F = ",+sum5)
print("Duration of S031F = ",+sum6)
print("Duration of S032F = ",+sum7)
print("Duration of S033F = ",+sum8)
print("Duration of S041F = ",+sum9)
print("Duration of S042F = ",+sum10)
print("Duration of S051F = ",+sum11)
print("Duration of S052F = ",+sum12)
print("Duration of S061F = ",+sum13)
print("Duration of S062F = ",+sum14)
print("Duration of S081F = ",+sum15)
print("Duration of S082F = ",+sum16)
print("Duration of S091F = ",+sum17)
print("Duration of S092F = ",+sum18)
print("Duration of S101F = ",+sum19)
print("Duration of S102F = ",+sum20)
print("Duration of S111F = ",+sum21)
print("Duration of S112F = ",+sum22)
print("Duration of S113F = ",+sum23)
print("Duration of S023M = ",+sum24)
print("Duration of S071M = ",+sum25)
print("Duration of S072M = ",+sum26)
print("Duration of S073M = ",+sum27)
# Out:
# Duration of S001F =  227.377729
# Duration of S002F =  252.3201959999999
# Duration of S011F =  229.36975900000004
# Duration of S012F =  207.18702300000004
# Duration of S021F =  749.331582
# Duration of S022F =  562.8693589999999
# Duration of S031F =  200.73689000000002
# Duration of S032F =  252.96298499999995
# Duration of S033F =  245.15835700000002
# Duration of S041F =  501.644545
# Duration of S042F =  611.8459030000002
# Duration of S051F =  236.87865899999997
# Duration of S052F =  489.33319799999987
# Duration of S061F =  298.51034599999997
# Duration of S062F =  408.898003
# Duration of S081F =  239.30545099999995
# Duration of S082F =  240.66940499999998
# Duration of S091F =  257.52476999999993
# Duration of S092F =  265.882758
# Duration of S101F =  307.3195149999999
# Duration of S102F =  293.017875
# Duration of S111F =  283.981577
# Duration of S112F =  315.13564699999995
# Duration of S113F =  311.17036899999994
# Duration of S023M =  472.1457469999999
# ...

# %%
female=sum+sum1+sum2+sum3+sum4+sum5+sum6+sum7+sum8+sum9+sum10+sum11+sum12+sum13+sum14+sum15+sum16+sum17+sum18+sum19+sum20+sum21+sum22+sum23
print("Durations of all female = ", + female)
male=sum24+sum25+sum26+sum27
print("Durations of all male = ", + male)
sibling00=sum+sum1
print("Durations of sibling00 = ", + sibling00)
sibling01=sum2+sum3
print("Durations of sibling01 = ", + sibling01)
sibling02=sum4+sum5+sum24
print("Durations of sibling02 = ", + sibling02)
sibling03=sum6+sum7+sum8 
print("Durations of sibling03 = ", + sibling03)
sibling04=sum9+sum10 
print("Durations of sibling04 = ", + sibling04)
sibling05=sum11+sum12 
print("Durations of sibling05 = ", + sibling05)
sibling06=sum13+sum14
print("Durations of sibling06 = ", + sibling06)
sibling07=sum25+sum26+sum27
print("Durations of sibling07 = ", + sibling07)
sibling08=sum15+sum16 
print("Durations of sibling08 = ", + sibling08)
sibling09=sum17+sum18
print("Durations of sibling09 = ", + sibling09)
sibling10=sum19+sum20
print("Durations of sibling10 = ", + sibling10)
sibling11=sum21+sum22+sum23
print("Durations of sibling11 = ", + sibling11)
# Out:
# Durations of all female =  7988.431901000002
# Durations of all male =  1240.834916
# Durations of sibling00 =  479.6979249999999
# Durations of sibling01 =  436.5567820000001
# Durations of sibling02 =  1784.346688
# Durations of sibling03 =  698.858232
# Durations of sibling04 =  1113.4904480000002
# Durations of sibling05 =  726.2118569999998
# Durations of sibling06 =  707.408349
# Durations of sibling07 =  768.689169
# Durations of sibling08 =  479.97485599999993
# Durations of sibling09 =  523.407528
# Durations of sibling10 =  600.3373899999999
# Durations of sibling11 =  910.2875929999999

# %%
twosibilings=sibling00+sibling01+sibling04+sibling05+sibling06+sibling08+sibling09+sibling10
print("Durations of two siblings groups = ", + twosibilings)
threesibilings=sibling02+sibling03+sibling07+sibling11
print("Durations of three siblings groups = ", + threesibilings)
Mixsibiling=sibling02
print("Durations of Mix (F & M) siblings groups = ", + Mixsibiling)
ARgroups=sibling00+sibling01+sibling03+sibling06+sibling07+sibling08+sibling09+sibling10+sibling11
print("Durations of AR languge groups + their ID in english = ", + ARgroups)
Mix_AR_EN=sibling02+sibling04+sibling05
print("Durations of mix AR and EN languge groups = ", + Mix_AR_EN)
IDenticaltwins=sibling09+sum22+sum23
print("Durations of identical twins = ", + IDenticaltwins)
notIDenticaltwins=sum6+sum7#جود و رهف
print("Durations of NOT identical twins = ", + notIDenticaltwins)
AllSpeaker=sum+sum1+sum2+sum3+sum4+sum5+sum6+sum7+sum8+sum9+sum10+sum11+sum12+sum13+sum14+sum15+sum16+sum17+sum18+sum19+sum20+sum21+sum22+sum23+sum24+sum25+sum26+sum27
print("Durations of All speakers = ", + AllSpeaker)
# Out:
# Durations of two siblings groups =  5067.085134999999
# Durations of three siblings groups =  4162.181682
# Durations of Mix (F & M) siblings groups =  1784.346688
# Durations of AR languge groups + their ID in english =  5605.217823999999
# Durations of mix AR and EN languge groups =  3624.048993
# Durations of identical twins =  1149.7135439999997
# Durations of NOT identical twins =  453.69987499999996
# Durations of All speakers =  9229.266817000003

# %%
sum0=0
train_file = "..\\data\\f_list\\lbl_list.txt"
file_paths = open(train_file,'r')
for path in file_paths:
    path = path.strip()
    file_name=os.path.basename(path)
    #print(file_name)
    split_filename=file_name.split('_')
    #print(split_filename)
    split_filename1=file_name.split('_')[0][4]
    #print(split_filename1)
    molecule_name=split_filename[0]
    #print(molecule_name)
    folder=Path(path).parts
    kk=folder[3]
    #print(kk)
    if kk=="EN":
        for pathlbl in path:
            file = open(path, "r")     
            times = []          
            for line in file:
                times.append([float(x) for x in line.strip().split( )[0:2]])
            file.close() 
        p=durations(times)
        #print(p)
        sum0 += p
print("Duration of EN <id,NE,WE,SE> = ",+sum0)
# Out:
# Duration of EN <id,NE,WE,SE> =  2588.4659720000004

# %%
sum00=0
train_file = "..\\data\\f_list\\lbl_list.txt"
file_paths = open(train_file,'r')
for path in file_paths:
    path = path.strip()
    file_name=os.path.basename(path)
    #print(file_name)
    split_filename=file_name.split('_')
    #print(split_filename)
    split_filename1=file_name.split('_')[0][4]
    #print(split_filename1)
    molecule_name=split_filename[0]
    #print(molecule_name)
    folder=Path(path).parts
    kk=folder[3]
    #print(kk)
    if kk=="AR":
        for pathlbl in path:
            file = open(path, "r")     
            times = []          
            for line in file:
                times.append([float(x) for x in line.strip().split( )[0:2]])
            file.close() 
        p=durations(times)
        #print(p)
        sum00 += p
print("Duration of AR <NA,WA,SA> = ",+sum00)
# Out:
# Duration of AR <NA,WA,SA> =  6640.800845000002
